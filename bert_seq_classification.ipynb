# %% [markdown]
# # BERT sequence classification

# %% [markdown]
# ## Load libraries

# %%
# !pip install transformers

# %%
import torch
from torch.utils.data import DataLoader, TensorDataset, random_split
from transformers import BertTokenizer, BertForSequenceClassification
import torch.optim as optim

# %% [markdown]
# ## Data preprocessing

# %%
# Define the sequences and labels
x = [
    [[1, 2], [3, 4], [5, 6]],
    [[0, -2], [3, 4]],
    []
]
y = [0, 1, 0]

# %%
# Make more data (fake) for example
x = x*100
y = y*100

# %%
# Initialize a BERT tokenizer
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

# Tokenize and pad sequences
# Get Max length of the sequence. Each element contains 4 tokens
max_seq_length = max(len(seq) for seq in x) * 4

# List of tokenized representations of the input sequences.
input_ids = []
# Listof attention masks (binary values (0 or 1))
attention_masks = []

for seq in x:
    input_seq = []
    attention_mask = []
    for item in seq:
        tokens = [str(num) for num in item]
        tokens = ['[CLS]'] + tokens + ['[SEP]']
        input_seq.extend(tokens)
        attention_mask.extend([1] * len(tokens))

    # Pad sequences to the same length
    while len(input_seq) < max_seq_length:
        input_seq.append('[PAD]')
        attention_mask.append(0)

    input_ids.append(tokenizer.convert_tokens_to_ids(input_seq))
    attention_masks.append(attention_mask)
# Out:
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]

# %%
# Convert lists to PyTorch tensors
input_ids = torch.tensor(input_ids)
attention_masks = torch.tensor(attention_masks)
labels = torch.tensor(y)

# %% [markdown]
# ## Data loader

# %%
# Create a DataLoader
dataset = TensorDataset(input_ids, attention_masks, labels)
batch_size = 16  # Adjustable

# %% [markdown]
# ### Train-Validation split

# %%
def train_test_split(dataset, train_ratio):
  """Train-test split"""
  train_size = int(train_ratio * len(dataset))
  val_size = len(dataset) - train_size
  train_dataset, val_dataset = random_split(dataset, [train_size, val_size])
  return train_dataset, val_dataset

# %%
# Divide the dataset by randomly selecting samples.
torch.manual_seed(0)
train_dataset, val_dataset = train_test_split(dataset, train_ratio=0.9)

# Create DataLoader
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_dataloader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

# %% [markdown]
# ## Fine-Tuning BERT Model

# %%
# Initialize a pre-trained BERT model for sequence classification
model = BertForSequenceClassification.from_pretrained('bert-base-uncased', num_labels=2)

# Define optimizer and learning rate
optimizer = optim.AdamW(model.parameters(), lr=1e-5)
# Out:
# Downloading model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# Fine-tuning
num_epochs = 3  # Adjustable
for epoch in range(num_epochs):
    model.train()
    total_loss = 0
    for batch in train_dataloader:
        input_ids_batch, attention_masks_batch, labels_batch = batch

        optimizer.zero_grad()

        # Forward pass
        outputs = model(input_ids_batch, attention_mask=attention_masks_batch, labels=labels_batch)
        loss = outputs.loss
        total_loss += loss.item()

        # Backward pass
        loss.backward()
        optimizer.step()

    # # Calculate average loss for this epoch
    # avg_loss = total_loss / len(dataloader)
    # print(f'Epoch {epoch + 1}/{num_epochs}, Loss: {avg_loss:.4f}')
        # Calculate average training loss for this epoch
        avg_train_loss = total_loss / len(train_dataloader)

        # Validation loop
        model.eval()
        val_loss = 0
        num_val_steps = 0

        for batch in val_dataloader:
            input_ids_batch, attention_masks_batch, labels_batch = batch

            with torch.no_grad():
                outputs = model(input_ids_batch, attention_mask=attention_masks_batch, labels=labels_batch)
                val_loss += outputs.loss.item()
                num_val_steps += 1

        avg_val_loss = val_loss / num_val_steps
        print(f'Epoch {epoch + 1}/{num_epochs}, Train Loss: {avg_train_loss:.4f}, Validation Loss: {avg_val_loss:.4f}')
# Out:
# Epoch 1/3, Train Loss: 0.0374, Validation Loss: 0.6439
# Epoch 1/3, Train Loss: 0.0761, Validation Loss: 0.5557
# Epoch 1/3, Train Loss: 0.1106, Validation Loss: 0.4577
# Epoch 1/3, Train Loss: 0.1376, Validation Loss: 0.3860
# Epoch 1/3, Train Loss: 0.1604, Validation Loss: 0.3523
# Epoch 1/3, Train Loss: 0.1807, Validation Loss: 0.3252
# Epoch 1/3, Train Loss: 0.1999, Validation Loss: 0.2932
# Epoch 1/3, Train Loss: 0.2168, Validation Loss: 0.2664
# Epoch 1/3, Train Loss: 0.2320, Validation Loss: 0.2441
# Epoch 1/3, Train Loss: 0.2446, Validation Loss: 0.2249
# Epoch 1/3, Train Loss: 0.2580, Validation Loss: 0.2098
# Epoch 1/3, Train Loss: 0.2713, Validation Loss: 0.1885
# Epoch 1/3, Train Loss: 0.2821, Validation Loss: 0.1754
# Epoch 1/3, Train Loss: 0.2919, Validation Loss: 0.1629
# Epoch 1/3, Train Loss: 0.3009, Validation Loss: 0.1479
# Epoch 1/3, Train Loss: 0.3078, Validation Loss: 0.1365
# Epoch 1/3, Train Loss: 0.3144, Validation Loss: 0.1289
# Epoch 2/3, Train Loss: 0.0091, Validation Loss: 0.1191
# Epoch 2/3, Train Loss: 0.0156, Validation Loss: 0.1106
# Epoch 2/3, Train Loss: 0.0220, Validation Loss: 0.1050
# Epoch 2/3, Train Loss: 0.0283, Validation Loss: 0.0968
# Epoch 2/3, Train Loss: 0.0334, Validation Loss: 0.0908
# Epoch 2/3, Train Loss: 0.0382, Validation Loss: 0.0861
# Epoch 2/3, Train Loss: 0.0426, Validation Loss: 0.0803
# Epoch 2/3, Train Loss: 0.0476, Validation Loss: 0.0751
# Epoch 2/3, Train Loss: 0.0511, Validation Loss: 0.0711
# Epoch 2/3, Train Loss: 0.0557, Validation Loss: 0.0670
# Epoch 2/3, Train Loss: 0.0591, Validation Loss: 0.0628
# Epoch 2/3, Train Loss: 0.0624, Validation Loss: 0.0590
# Epoch 2/3, Train Loss: 0.0657, Validation Loss: 0.0559
# Epoch 2/3, Train Loss: 0.0690, Validation Loss: 0.0529
# Epoch 2/3, Train Loss: 0.0721, Validation Loss: 0.0500
# Epoch 2/3, Train Loss: 0.0752, Validation Loss: 0.0472
# Epoch 2/3, Train Loss: 0.0779, Validation Loss: 0.0447
# Epoch 3/3, Train Loss: 0.0038, Validation Loss: 0.0432
# Epoch 3/3, Train Loss: 0.0064, Validation Loss: 0.0416
# Epoch 3/3, Train Loss: 0.0084, Validation Loss: 0.0394
# Epoch 3/3, Train Loss: 0.0108, Validation Loss: 0.0370
# Epoch 3/3, Train Loss: 0.0129, Validation Loss: 0.0348
# Epoch 3/3, Train Loss: 0.0152, Validation Loss: 0.0334
# Epoch 3/3, Train Loss: 0.0171, Validation Loss: 0.0323
# Epoch 3/3, Train Loss: 0.0191, Validation Loss: 0.0307
# Epoch 3/3, Train Loss: 0.0207, Validation Loss: 0.0290
# Epoch 3/3, Train Loss: 0.0220, Validation Loss: 0.0278
# Epoch 3/3, Train Loss: 0.0235, Validation Loss: 0.0270
# Epoch 3/3, Train Loss: 0.0249, Validation Loss: 0.0260
# Epoch 3/3, Train Loss: 0.0263, Validation Loss: 0.0249
# Epoch 3/3, Train Loss: 0.0278, Validation Loss: 0.0237
# Epoch 3/3, Train Loss: 0.0293, Validation Loss: 0.0227
# Epoch 3/3, Train Loss: 0.0305, Validation Loss: 0.0220
# Epoch 3/3, Train Loss: 0.0317, Validation Loss: 0.0214

# %%
# Save or use the fine-tuned model
torch.save(model.state_dict(), 'bert_sequence_classification.pth')
